# %%
import pandas as pd
import numpy as np
from datetime import date
import datetime

df = pd.read_csv('data/final_date.csv')

class EventAnalyzer:
    def __init__(self, df):
        self.df = df

#------------------------------------------------------------
# private method
#------------------------------------------------------------

    def _get_combined_dates(self, event_names):
        # 여러 이벤트 이름에 해당하는 날짜들을 하나의 리스트로 합쳐 반환합니다.
        combined_dates = []
        for event_name in event_names:
            row = self.df[self.df['event_name'] == event_name].iloc[0, 1:].dropna()
            dates = [datetime.datetime.strptime(str(date).replace('.', '-'), '%Y-%m-%d').date() for date in row]
            combined_dates.extend(dates)
        
        combined_dates.sort()
        return combined_dates
    
#------------------------------------------------------------
# public method
#------------------------------------------------------------

    def event_intervals(self, event_names, start_year=None, end_year=2023):
        # 합쳐진 여러 이벤트 이름에 대해 연속된 날짜 간의 간격을 반환합니다.
        dates = self._get_combined_dates(event_names)
        if start_year:
            dates = [date for date in dates if start_year <= date.year <= end_year]
        intervals = [(dates[i+1] - dates[i]).days for i in range(len(dates)-1)]
        return intervals

    def event_counts_by_year(self, event_names, start_year=None, end_year=2023):
        # 합쳐진 여러 이벤트 이름에 대해 연도별 발생 횟수를 반환합니다.
        dates = self._get_combined_dates(event_names)
        if start_year:
            dates = [date for date in dates if start_year <= date.year <= end_year]
        counts = {}
        for date in dates:
            year = date.year
            if year in counts:
                counts[year] += 1
            else:
                counts[year] = 1
        return counts

    def get_event_intervals_by_year(self, event_name, year, start_year=None, end_year=2023):
        # 주어진 event_name과 year 정보를 바탕으로 해당 year에 실행된 date 간의 간격을 반환합니다.
        dates = self._get_combined_dates([event_name])
        if start_year:
            dates = [date for date in dates if start_year <= date.year <= end_year]
        dates_of_year = [date for date in dates if date.year == year]
        intervals = [(dates_of_year[i+1] - dates_of_year[i]).days for i in range(len(dates_of_year)-1)]
        return intervals

    def get_event_summary(self, start_year=2017, end_year=2023):
        # 각 이벤트의 주어진 연도 범위 내에서의 발생 횟수, 간격의 평균 및 표준편차 정보를 담은 데이터 프레임을 반환합니다.
        years = list(range(start_year, end_year+1))
        event_names = self.df['event_name'].tolist()
        
        data = []
        for event_name in event_names:
            yearly_counts = []
            yearly_avg_intervals = []
            yearly_std_intervals = []
            for year in years:
                yearly_counts.append(self.event_counts_by_year([event_name], start_year, end_year).get(year, 0))
                yearly_intervals = self.get_event_intervals_by_year(event_name, year, start_year, end_year)
                yearly_avg_intervals.append(np.mean(yearly_intervals) if yearly_intervals else None)
                yearly_std_intervals.append(np.std(yearly_intervals) if yearly_intervals else None)
            
            overall_intervals = self.event_intervals([event_name], start_year, end_year)
            overall_avg_interval = np.mean(overall_intervals) if overall_intervals else None
            overall_std_interval = np.std(overall_intervals) if overall_intervals else None

            data_row = yearly_counts + yearly_avg_intervals + yearly_std_intervals + [overall_avg_interval, overall_std_interval]
            data.append(data_row)
        
        columns = (
            [f"Count_{year}" for year in years] +
            [f"Avg_Interval_{year}" for year in years] +
            [f"Std_Interval_{year}" for year in years] +
            ["Overall_Avg_Interval", "Overall_Std_Interval"]
        )
        summary_df = pd.DataFrame(data, columns=columns, index=event_names)
        
        return summary_df

# 테스트
analyzer = EventAnalyzer(df)
event_summary_result = analyzer.get_event_summary(start_year=2021)
event_summary_result
# Out:
#                                                    Count_2021  Count_2022  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                6           4
# 룬 경험치 버프 효과 +100%                                          11          11
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                        5           4
# 몬스터 파크 클리어 경험치 추가 50%                                       6           7
# 미라클 타임                                                      1           2
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                  5           5
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                         7           7
# 스타포스 강화 비용 30% 할인                                           6           6
# 어빌리티 재설정 비용 50% 할인                                          7           7
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가           9          10
# 경험치 쿠폰 지급                                                   0           0
# 선택 아케인심볼 교환권 지급                                             6           2
#
#                                                    Count_2023  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                4
# 룬 경험치 버프 효과 +100%                                           6
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                        2
# 몬스터 파크 클리어 경험치 추가 50%                                       7
# 미라클 타임                                                      2
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                  4
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                         4
# 스타포스 강화 비용 30% 할인                                           5
# 어빌리티 재설정 비용 50% 할인                                          5
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가           6
# 경험치 쿠폰 지급                                                   2
# 선택 아케인심볼 교환권 지급                                             0
#
#                                                    Avg_Interval_2021  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                  51.800
# 룬 경험치 버프 효과 +100%                                             31.500
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                          68.250
# 몬스터 파크 클리어 경험치 추가 50%                                         56.000
# 미라클 타임                                                           NaN
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                    56.000
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                           56.000
# 스타포스 강화 비용 30% 할인                                             53.200
# 어빌리티 재설정 비용 50% 할인                                            52.500
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가             30.625
# 경험치 쿠폰 지급                                                        NaN
# 선택 아케인심볼 교환권 지급                                               64.400
#
#                                                    Avg_Interval_2022  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                               72.333333
# 룬 경험치 버프 효과 +100%                                          32.900000
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                       81.666667
# 몬스터 파크 클리어 경험치 추가 50%                                      50.166667
# 미라클 타임                                                    189.000000
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                 66.500000
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                        52.500000
# 스타포스 강화 비용 30% 할인                                          57.400000
# 어빌리티 재설정 비용 50% 할인                                         56.000000
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가          37.333333
# 경험치 쿠폰 지급                                                        NaN
# 선택 아케인심볼 교환권 지급                                            77.000000
#
#                                                    Avg_Interval_2023  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                               54.666667
# 룬 경험치 버프 효과 +100%                                          28.000000
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                       84.000000
# 몬스터 파크 클리어 경험치 추가 50%                                      33.833333
# 미라클 타임                                                    182.000000
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                 63.666667
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                        56.333333
# 스타포스 강화 비용 30% 할인                                          42.250000
# 어빌리티 재설정 비용 50% 할인                                         43.250000
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가          32.200000
# 경험치 쿠폰 지급                                                 126.000000
# 선택 아케인심볼 교환권 지급                                                  NaN
#
#                                                    Std_Interval_2021  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                5.600000
# 룬 경험치 버프 효과 +100%                                           8.991663
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                       47.314770
# 몬스터 파크 클리어 경험치 추가 50%                                      27.647785
# 미라클 타임                                                           NaN
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                  4.949747
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                        11.430952
# 스타포스 강화 비용 30% 할인                                           9.495262
# 어빌리티 재설정 비용 50% 할인                                         31.500000
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가           6.945097
# 경험치 쿠폰 지급                                                        NaN
# 선택 아케인심볼 교환권 지급                                            32.952086
#
#                                                    Std_Interval_2022  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                               11.897712
# 룬 경험치 버프 효과 +100%                                          11.734138
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                       47.590849
# 몬스터 파크 클리어 경험치 추가 50%                                      33.672029
# 미라클 타임                                                      0.000000
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                 31.500000
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                        24.500000
# 스타포스 강화 비용 30% 할인                                          16.800000
# 어빌리티 재설정 비용 50% 할인                                         15.121728
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가          22.622506
# 경험치 쿠폰 지급                                                        NaN
# 선택 아케인심볼 교환권 지급                                             0.000000
#
#                                                    Std_Interval_2023  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                               17.249799
# 룬 경험치 버프 효과 +100%                                           8.854377
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                        0.000000
# 몬스터 파크 클리어 경험치 추가 50%                                      13.655483
# 미라클 타임                                                      0.000000
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                  5.792716
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                        28.170118
# 스타포스 강화 비용 30% 할인                                          30.384001
# 어빌리티 재설정 비용 50% 할인                                         26.611792
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가          15.078461
# 경험치 쿠폰 지급                                                   0.000000
# 선택 아케인심볼 교환권 지급                                                  NaN
#
#                                                    Overall_Avg_Interval  \
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                  65.692308
# 룬 경험치 버프 효과 +100%                                             31.888889
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                          81.200000
# 몬스터 파크 클리어 경험치 추가 50%                                         48.263158
# 미라클 타임                                                       227.500000
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                    63.538462
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                           53.529412
# 스타포스 강화 비용 30% 할인                                             55.125000
# 어빌리티 재설정 비용 50% 할인                                            50.555556
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가             34.708333
# 경험치 쿠폰 지급                                                    126.000000
# 선택 아케인심볼 교환권 지급                                               69.000000
#
#                                                    Overall_Std_Interval
# 10성 이하에서 스타포스 강화 성공 시 1+1 강화                                  28.778690
# 룬 경험치 버프 효과 +100%                                             10.140982
# 몬스터 컬렉션 '의문의 모몽' 지급, 신규 몬스터 등록 확률 추가                          41.906563
# 몬스터 파크 클리어 경험치 추가 50%                                         28.265363
# 미라클 타임                                                        74.821454
# 소울 조각 사용 시 위대한 소울 획득 확률 5배                                    20.144155
# 스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                           21.180228
# 스타포스 강화 비용 30% 할인                                             21.937055
# 어빌리티 재설정 비용 50% 할인                                            24.748114
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가             16.843592
# 경험치 쿠폰 지급                                                      0.000000
# 선택 아케인심볼 교환권 지급                                               28.844410

# %%
events_name = list(analyzer.data_count().keys())

for i in range(len(events_name)):
    for j in range(len(events_name)):
        if i == j:
            continue
        common_dates = analyzer.get_common_dates(events_name[i], events_name[j])
        ratio = len(common_dates) / min(analyzer.data_count()[events_name[i]], analyzer.data_count()[events_name[j]])
        if ratio > 0.2:
            print(events_name[i],',' ,events_name[j],':' ,ratio, (analyzer.get_common_dates(events_name[i], events_name[j])))
# Out:
# 룬 경험치 버프 효과 +100% , 몬스터 파크 클리어 경험치 추가 50% : 0.20689655172413793 ['2021-09-12', '2021-10-31', '2022-01-30', '2022-04-24', '2022-09-25', '2022-10-09']
# 몬스터 파크 클리어 경험치 추가 50% , 룬 경험치 버프 효과 +100% : 0.20689655172413793 ['2021-09-12', '2021-10-31', '2022-01-30', '2022-04-24', '2022-09-25', '2022-10-09']
# 몬스터 파크 클리어 경험치 추가 50% , 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가 : 0.2413793103448276 ['2021-05-02', '2022-08-07', '2022-09-25', '2023-01-08', '2023-02-19', '2023-04-16', '2023-04-30']
# 소울 조각 사용 시 위대한 소울 획득 확률 5배 , 어빌리티 재설정 비용 50% 할인 : 0.2857142857142857 ['2018-09-09', '2018-12-30', '2019-03-17', '2019-07-28', '2019-09-15', '2019-12-15', '2020-02-09', '2021-10-10', '2022-09-25', '2023-05-14']
# 어빌리티 재설정 비용 50% 할인 , 소울 조각 사용 시 위대한 소울 획득 확률 5배 : 0.2857142857142857 ['2018-09-09', '2018-12-30', '2019-03-17', '2019-07-28', '2019-09-15', '2019-12-15', '2020-02-09', '2021-10-10', '2022-09-25', '2023-05-14']
# 폴로와 프리토, 에스페시아의 현상금 사냥 경험치, 불꽃늑대 퇴장 시 획득하는 경험치 추가 , 몬스터 파크 클리어 경험치 추가 50% : 0.2413793103448276 ['2021-05-02', '2022-08-07', '2022-09-25', '2023-01-08', '2023-02-19', '2023-04-16', '2023-04-30']

# %%
analyzer.event_intervals(['어빌리티 재설정 비용 50% 할인'])
# Out:
# [42,
#  56,
#  91,
#  196,
#  133,
#  70,
#  42,
#  77,
#  42,
#  49,
#  42,
#  49,
#  91,
#  56,
#  35,
#  84,
#  35,
#  35,
#  63,
#  49,
#  35,
#  119,
#  56,
#  21,
#  42,
#  35,
#  42,
#  56,
#  77,
#  70,
#  42,
#  63,
#  35,
#  49,
#  30,
#  5,
#  77,
#  35,
#  56]

# %%
analyzer.get_event_summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 analyzer.get_event_summary()
#
# AttributeError: 'EventAnalyzer' object has no attribute 'get_event_summary'
