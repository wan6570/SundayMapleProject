# %%
# Import necessary libraries
import pandas as pd
from collections import defaultdict
from datetime import datetime
import re
import numpy as np

# Define the function to parse date and interval
def parse_date_interval_v2(cell):
    if pd.isna(cell):
        return np.nan, np.nan
    else:
        # Remove additional time info
        cell = re.sub(r"\(오전.*?\)", "", cell)  # remove everything inside parentheses
        cell = re.sub(r"\(오후.*?\)", "", cell)
        cell = re.sub(r"\(하루 종일\)", "", cell)
        cell = cell.strip()

        # Check if date interval is present
        interval_match = re.search(r"\((\+?\d+).*?일\)", cell)
        if interval_match:
            interval = int(interval_match.group(1))
        else:
            interval = np.nan

        # Parse date
        date_match = re.search(r"(\d{4}.\d{2}.\d{2})", cell)
        if date_match:
            date_str = date_match.group(0).strip()
            date = datetime.strptime(date_str, '%Y.%m.%d')
        else:
            date = np.nan
            
        return date, interval

# Load the data
data_path = "processed_data.csv"
df = pd.read_csv(data_path)

# Initialize data for new dataframe
new_data = defaultdict(list)

# Iterate over events
for i, row in df.iterrows():
    event_name = row['events']
    new_data['events'].append(event_name)

    # Initialize lists to store dates and intervals
    dates = []
    intervals = []

    # Initialize a dict to count events per year
    event_count_per_year = defaultdict(int)

    # Iterate over dates in the event row
    for cell in row[1:]:
        date, interval = parse_date_interval_v2(cell)

        # Store the date and interval if they are not NaN
        if not pd.isna(date):
            dates.append(date)
            event_count_per_year[date.year] += 1
        if not pd.isna(interval):
            intervals.append(interval)

    # Compute desired statistics
    total_event_count = len(dates)
    most_recent_event_date = max(dates) if dates else np.nan
    avg_interval = np.mean(intervals) if intervals else np.nan
    std_interval = np.std(intervals) if intervals else np.nan

    # Store the statistics in the new data
    new_data['total_event_count'].append(total_event_count)
    new_data['most_recent_event_date'].append(most_recent_event_date)
    new_data['avg_interval'].append(avg_interval)
    new_data['std_interval'].append(std_interval)

    # Store the event counts per year
    for year in range(2017, 2024):
        new_data[f'event_count_{year}'].append(event_count_per_year[year])

# Create a new dataframe from the new data
new_df = pd.DataFrame(new_data)

# Display the new dataframe
new_df

# %%
new_df.to_csv('final_df.csv')

# %%
new_df
# Out:
#                                  events  total_event_count  \
# 0                                경험치 2배                  4
# 1                  경험치 3배 쿠폰(15분) 2장 지급                  4
# 2                  경험치 3배 쿠폰(30분) 4장 지급                  1
# 3                        레이디 블레어의 코디 타임                  1
# 4                     룬 경험치 버프 효과 +100%                 47
# 5                몬스터 컬렉션 '의문의 모몽' 3개 지급                 17
# 6          몬스터 컬렉션 신규 몬스터 등록 확률 추가 100%                 22
# 7                 몬스터 파크 클리어 경험치 추가 50%                 29
# 8                                미라클 타임                  7
# 9                 불꽃늑대 퇴장 시 획득하는 경험치 2배                 42
# 10           소울 조각 사용 시 위대한 소울 획득 확률 5배                 35
# 11                    솜사탕 핑크빈 교환권 1개 지급                  1
# 12  스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                 37
# 13                    스타포스 강화 비용 30% 할인                 42
# 14                   어빌리티 재설정 비용 50% 할인                 40
# 15          역대 마스터 라벨 풀 패키지 교환권 중 1개 지급                  1
# 16                          익스트림 레벨업 타임                  3
# 17                    익스트림 성장의 비약 5개 지급                  2
# 18                  주문의 흔적 강화 비용 50% 할인                 40
# 19                    콤보킬 경험치 획득량 +300%                 45
# 20                         테라 버닝 부스터 지급                  1
# 21               폴로와 프리토의 현상금 사냥 경험치 2배                 31
# 22         폴로와 프리토 에스페시아의 현상금 사냥 경험치 2배                 11
#
#    most_recent_event_date  avg_interval  std_interval  event_count_2017  \
# 0              2022-05-01    487.666667    301.587282                 0
# 1              2023-03-26    644.000000    816.713332                 1
# 2              2023-07-30           NaN           NaN                 0
# 3              2022-08-14    175.000000      0.000000                 0
# 4              2023-06-18     49.456522     45.280626                 3
# 5              2023-06-04    105.437500     80.669828                 0
# 6              2023-06-04     95.333333     54.841185                 1
# 7              2023-07-30     62.750000     54.974426                 0
# 8              2023-07-16    274.166667     89.954464                 0
# 9              2023-06-18     49.341463     30.802763                 1
# 10             2023-07-23     67.117647     25.830630                 4
# 11             2022-09-18           NaN           NaN                 0
# 12             2023-07-02     63.583333     29.014723                 5
# 13             2023-07-02     55.146341     28.586677                 6
# 14             2023-07-09     58.512821     33.380381                 4
# 15             2022-09-18           NaN           NaN                 0
# 16             2022-09-11    129.500000     45.500000                 0
# 17             2022-10-02    154.000000      0.000000                 0
# 18             2023-07-23     50.076923     23.188619                 0
# 19             2023-06-18     46.136364     36.717961                 1
# 20             2023-07-09           NaN           NaN                 0
# 21             2022-05-08     54.133333     32.629979                 1
# 22             2023-06-18     36.909091     22.354396                 0
#
#     event_count_2018  event_count_2019  event_count_2020  event_count_2021  \
# 0                  1                 2                 0                 0
# 1                  2                 0                 0                 0
# 2                  0                 0                 0                 0
# 3                  0                 0                 0                 0
# 4                  4                 3                 9                11
# 5                  1                 2                 3                 5
# 6                  2                 3                 3                 6
# 7                  2                 1                 6                 6
# 8                  0                 1                 1                 1
# 9                  3                 5                 8                 9
# 10                 5                 6                 6                 5
# 11                 0                 0                 0                 0
# 12                 5                 6                 3                 7
# 13                 4                 9                 6                 6
# 14                 4                 6                 7                 7
# 15                 0                 0                 0                 0
# 16                 0                 0                 0                 1
# 17                 0                 0                 0                 0
# 18                 5                 5                 7                 9
# 19                 4                 3                 9                11
# 20                 0                 0                 0                 0
# 21                 3                 5                 8                 9
# 22                 0                 0                 0                 0
#
#     event_count_2022  event_count_2023
# 0                  1                 0
# 1                  0                 1
# 2                  0                 1
# 3                  1                 0
# 4                 11                 6
# 5                  4                 2
# 6                  5                 2
# 7                  7                 7
# 8                  2                 2
# 9                 10                 6
# 10                 5                 4
# 11                 1                 0
# 12                 7                 4
# 13                 6                 5
# 14                 7                 5
# 15                 1                 0
# 16                 2                 0
# 17                 2                 0
# 18                 7                 7
# 19                11                 6
# 20                 0                 1
# 21                 5                 0
# 22                 5                 6

# %%
new_df.columns
# Out:
# Index(['events', 'total_event_count', 'most_recent_event_date', 'avg_interval',
#        'std_interval', 'event_count_2017', 'event_count_2018',
#        'event_count_2019', 'event_count_2020', 'event_count_2021',
#        'event_count_2022', 'event_count_2023'],
#       dtype='object')

# %%
new_df['most_recent_event_date'].describe()
# Out:
# C:\Users\jongwan\AppData\Local\Temp\ipykernel_22928\1829623640.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   new_df['most_recent_event_date'].describe()
# count                      23
# unique                     14
# top       2023-06-18 00:00:00
# freq                        4
# first     2022-05-01 00:00:00
# last      2023-07-30 00:00:00
# Name: most_recent_event_date, dtype: object

# %%
new_df['most_recent_event_date'].value_counts()
# Out:
# 2023-06-18    4
# 2023-07-30    2
# 2023-06-04    2
# 2023-07-23    2
# 2022-09-18    2
# 2023-07-02    2
# 2023-07-09    2
# 2022-05-01    1
# 2023-03-26    1
# 2022-08-14    1
# 2023-07-16    1
# 2022-09-11    1
# 2022-10-02    1
# 2022-05-08    1
# Name: most_recent_event_date, dtype: int64

# %%
new_df.loc[new_df['most_recent_event_date'] == '2023-06-18', :]
# Out:
#                           events  total_event_count most_recent_event_date  \
# 4              룬 경험치 버프 효과 +100%                 47             2023-06-18
# 9          불꽃늑대 퇴장 시 획득하는 경험치 2배                 42             2023-06-18
# 19             콤보킬 경험치 획득량 +300%                 45             2023-06-18
# 22  폴로와 프리토 에스페시아의 현상금 사냥 경험치 2배                 11             2023-06-18
#
#     avg_interval  std_interval  event_count_2017  event_count_2018  \
# 4      49.456522     45.280626                 3                 4
# 9      49.341463     30.802763                 1                 3
# 19     46.136364     36.717961                 1                 4
# 22     36.909091     22.354396                 0                 0
#
#     event_count_2019  event_count_2020  event_count_2021  event_count_2022  \
# 4                  3                 9                11                11
# 9                  5                 8                 9                10
# 19                 3                 9                11                11
# 22                 0                 0                 0                 5
#
#     event_count_2023
# 4                  6
# 9                  6
# 19                 6
# 22                 6
