# %%
import numpy as np
import pandas as pd
import re
from datetime import datetime
from collections import defaultdict

# Define the function to parse date and interval
def parse_date_interval(cell):
    if pd.isna(cell):
        return np.nan, np.nan
    else:
        # Check if date interval is present
        interval_match = re.search(r"\((\+?\d+).*?일\)", cell)
        if interval_match:
            interval = int(interval_match.group(1))
        else:
            interval = np.nan

        # Parse date
        date_match = re.search(r"\)(.+)", cell)
        if date_match:
            date_str = date_match.group(1).strip()

            # Remove additional info
            date_str = re.sub(r"\(.+?\)", "", date_str)  # remove everything inside parentheses
            date_str = date_str.replace("오전", "").replace("오후", "").strip()  # remove "오전" and "오후"
            date = datetime.strptime(date_str, '%Y.%m.%d')
        else:
            date = np.nan
            
        return date, interval

# Load the data
data_path = "processed_data.csv"
df = pd.read_csv(data_path)

# Initialize data for new dataframe
new_data = defaultdict(list)

# Iterate over events
for i, row in df.iterrows():
    event_name = row['events']
    new_data['events'].append(event_name)

    # Initialize lists to store dates and intervals
    dates = []
    intervals = []

    # Initialize a dict to count events per year
    event_count_per_year = defaultdict(int)

    # Iterate over dates in the event row
    for cell in row[1:]:
        date, interval = parse_date_interval(cell)

        # Store the date and interval if they are not NaN
        if not pd.isna(date):
            dates.append(date)
            event_count_per_year[date.year] += 1
        if not pd.isna(interval):
            intervals.append(interval)

    # Compute desired statistics
    total_event_count = len(dates)
    most_recent_event_date = max(dates) if dates else np.nan
    avg_interval = np.mean(intervals) if intervals else np.nan
    std_interval = np.std(intervals) if intervals else np.nan

    # Store the statistics in the new data
    new_data['total_event_count'].append(total_event_count)
    new_data['most_recent_event_date'].append(most_recent_event_date)
    new_data['avg_interval'].append(avg_interval)
    new_data['std_interval'].append(std_interval)

    # Store the event counts per year
    for year in range(2017, 2024):
        new_data[f'event_count_{year}'].append(event_count_per_year[year])

# Create a new dataframe from the new data
new_df = pd.DataFrame(new_data)

# Display the new dataframe
new_df
# Out:
#                                  events  total_event_count  event_count_2021  \
# 0                                경험치 2배                  3                 0
# 1                  경험치 3배 쿠폰(15분) 2장 지급                  3                 0
# 2                  경험치 3배 쿠폰(30분) 4장 지급                  0                 0
# 3                        레이디 블레어의 코디 타임                  1                 0
# 4                     룬 경험치 버프 효과 +100%                 46                11
# 5                몬스터 컬렉션 '의문의 모몽' 3개 지급                 16                 5
# 6          몬스터 컬렉션 신규 몬스터 등록 확률 추가 100%                 21                 6
# 7                 몬스터 파크 클리어 경험치 추가 50%                 28                 6
# 8                                미라클 타임                  6                 1
# 9                 불꽃늑대 퇴장 시 획득하는 경험치 2배                 41                 9
# 10           소울 조각 사용 시 위대한 소울 획득 확률 5배                 34                 5
# 11                    솜사탕 핑크빈 교환권 1개 지급                  0                 0
# 12  스타포스 5, 10, 15성에서 강화 시도 시 성공확률 100%                 36                 7
# 13                    스타포스 강화 비용 30% 할인                 41                 6
# 14                   어빌리티 재설정 비용 50% 할인                 39                 7
# 15          역대 마스터 라벨 풀 패키지 교환권 중 1개 지급                  0                 0
# 16                          익스트림 레벨업 타임                  2                 0
# 17                    익스트림 성장의 비약 5개 지급                  1                 0
# 18                  주문의 흔적 강화 비용 50% 할인                 39                 9
# 19                    콤보킬 경험치 획득량 +300%                 44                11
# 20                         테라 버닝 부스터 지급                  0                 0
# 21               폴로와 프리토의 현상금 사냥 경험치 2배                 30                 9
# 22         폴로와 프리토 에스페시아의 현상금 사냥 경험치 2배                 11                 0
#
#     event_count_2022  event_count_2023 most_recent_event_date  avg_interval  \
# 0                  1                 0             2022-05-01    487.666667
# 1                  0                 1             2023-03-26    644.000000
# 2                  0                 0                    NaT           NaN
# 3                  1                 0             2022-08-14    175.000000
# 4                 11                 6             2023-06-18     49.456522
# 5                  4                 2             2023-06-04    105.437500
# 6                  5                 2             2023-06-04     95.333333
# 7                  7                 7             2023-07-30     62.750000
# 8                  2                 2             2023-07-16    274.166667
# 9                 10                 6             2023-06-18     49.341463
# 10                 5                 4             2023-07-23     67.117647
# 11                 0                 0                    NaT           NaN
# 12                 7                 4             2023-07-02     63.583333
# 13                 6                 5             2023-07-02     55.146341
# 14                 7                 5             2023-07-09     58.512821
# 15                 0                 0                    NaT           NaN
# 16                 2                 0             2022-09-11    129.500000
# 17                 1                 0             2022-10-02    154.000000
# 18                 7                 7             2023-07-23     50.076923
# 19                11                 6             2023-06-18     46.136364
# 20                 0                 0                    NaT           NaN
# 21                 5                 0             2022-05-08     54.133333
# 22                 5                 6             2023-06-18     36.909091
#
#     std_interval
# 0     301.587282
# 1     816.713332
# 2            NaN
# 3       0.000000
# 4      45.280626
# 5      80.669828
# 6      54.841185
# 7      54.974426
# 8      89.954464
# 9      30.802763
# 10     25.830630
# 11           NaN
# 12     29.014723
# 13     28.586677
# 14     33.380381
# 15           NaN
# 16     45.500000
# 17      0.000000
# 18     23.188619
# 19     36.717961
# 20           NaN
# 21     32.629979
# 22     22.354396
